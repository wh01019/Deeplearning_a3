# %%
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
from keras.optimizers import Adam, RMSprop
from keras.models import load_model
import sys
sys.path.append(r'C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\src')
from data_preparation import StockIndexDataset
from rnn_models import *
from utils import plot_seqs, create_labels

# %%
# Set constant variables and hyper-parameters for the model training

INPUT_PATH = r"C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\src\data"
OUTPUT_PATH = r'C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models' 
os.makedirs(OUTPUT_PATH, exist_ok=True)
# Load datasets
datasets_path = [os.path.join(INPUT_PATH, file) for file in sorted(os.listdir(INPUT_PATH))]
for p in datasets_path:
    print(p)

RNN_params = {"batch_size": 32,
              "epochs": 120,
              "lr": 1e-4,
              "time_steps": 12,
              "forecast_steps": 6,
              "window": 12,
              "RNN_size": 128,
              "FC_size": 32,
              "optim": Adam,
              "dropout": 0.5,
              "earlystop": {"patience": 20, 
                            "min_delta": 0.00001},
              "reduce_lr": {"factor": 0.1,
                            "patience": 10,
                            "min_delta": 0.0001}
              }

GRU_params = {"batch_size": 32,
              "epochs": 120,
              "lr": 1e-4,
              "time_steps": 6,
              "forecast_steps": 6,
              "window": 12,
              "RNN_size": 128,
              "FC_size": 32,
              "optim": Adam,
              "dropout": 0.5,
              "earlystop": {"patience": 20, 
                            "min_delta": 0.00001},
              "reduce_lr": {"factor": 0.1,
                            "patience": 10,
                            "min_delta": 0.0001}
              }

LSTM_params = {"batch_size": 32,
               "epochs": 120,
               "lr": 1e-4,
               "time_steps": 6,
               "forecast_steps": 6,
               "window": 12,
               "RNN_size": 128,
               "FC_size": 32,
               "optim": Adam,
               "dropout": 0.5,
               "earlystop": {"patience": 20, 
                             "min_delta": 0.00001},
               "reduce_lr": {"factor": 0.1,
                             "patience": 10,
                             "min_delta": 0.0001}
               }

def display_learningcurve(modelhist):
    df = pd.DataFrame(modelhist.history)

    # Display the first few rows
    print("DataFrame preview:")
    print(df.head())

    # Plot Loss
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(df.index + 1, df['loss'], label='Training Loss')
    plt.plot(df.index + 1, df['val_loss'], label='Validation Loss')
    plt.title('Loss vs. Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(df.index + 1, df['mda'], label='Training MDA')
    plt.plot(df.index + 1, df['val_mda'], label='Validation MDA')
    plt.title('Mean Directional Accuracy vs. Epochs')
    plt.xlabel('')
    plt.ylabel('Mean Directional Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

def trainRNN(datasets_path, params):
    data = StockIndexDataset(datasets_path, time_steps=params['time_steps'],
                            forecast_steps=params['forecast_steps'],
                            batch_size=params['batch_size'], val_ratio=.1, test_ratio=.1)
    data.info()
    
    input = (data.batch_size, data.time_steps, data.X_train.shape[2])
    model = build_SimpleRNN(input, params)
    filepath = os.path.join(OUTPUT_PATH, "RNN_bestweights.keras")
    callbacks = training_callbacks(['reduce_lr', 'mcp'], params,filepath) 
    hist = model.fit(data.X_train, data.y_train, 
                         epochs=params["epochs"], batch_size=data.batch_size,
                         shuffle=False, validation_data=(data.X_val, data.y_val), 
                         verbose=2, callbacks=callbacks)
    display_learningcurve(hist)

    predictions = ModelPredictions(model, 
                                    X = data.X, 
                                    y = data.y, 
                                    raw_y = data.raw_seq[:,1], 
                                    datetime = data.datetime,
                                    window = params['window'],
                                    batch_size = params['batch_size'])

    labels = ['Actual', 'Training', 'Validation', 'Test']
    predictions.plot_predictions(title="SH300IF (RNN model)", labels=labels)

    return predictions

def trainGRU(datasets_path, params):
    data = StockIndexDataset(datasets_path, time_steps=params['time_steps'],
                            forecast_steps=params['forecast_steps'],
                            batch_size=params['batch_size'], val_ratio=.1, test_ratio=.1)

    input = (data.batch_size, data.time_steps, data.X_train.shape[2])
    model = build_GRU(input, params)
    filepath = os.path.join(OUTPUT_PATH,"GRU_bestweights.keras") 
    callbacks = training_callbacks(['reduce_lr', 'mcp'], params,filepath) 
    hist = model.fit(data.X_train, data.y_train, 
                         epochs=params["epochs"], batch_size=data.batch_size,
                         shuffle=False, validation_data=(data.X_val, data.y_val), 
                         verbose=2, callbacks=callbacks)
    display_learningcurve(hist)
    predictions = ModelPredictions(model, 
                                    X = data.X, 
                                    y = data.y, 
                                    raw_y = data.raw_seq[:,1], 
                                    datetime = data.datetime,
                                    window = params['window'],
                                    batch_size = params['batch_size'])

    labels = ['Actual', 'Training', 'Validation', 'Test']
    predictions.plot_predictions(title="SH300IF (GRU model)", labels=labels)
    return predictions

def trainLSTM(datasets_path, params):
    data = StockIndexDataset(datasets_path, time_steps=params['time_steps'],
                            forecast_steps=params['forecast_steps'],
                            batch_size=params['batch_size'], val_ratio=.1, test_ratio=.1)
    data.info()

    input = (data.batch_size, data.time_steps, data.X_train.shape[2])
    model = build_LSTM(input, params)
    filepath = os.path.join(OUTPUT_PATH,"LSTM_bestweights.keras") 
    callbacks = training_callbacks(['reduce_lr', 'mcp'], params,filepath) 
    hist = model.fit(data.X_train, data.y_train, 
                         epochs=params["epochs"], batch_size=data.batch_size,
                         shuffle=False, validation_data=(data.X_val, data.y_val), 
                         verbose=2, callbacks=callbacks)
    display_learningcurve(hist)
    predictions = ModelPredictions(model, 
                                    X = data.X, 
                                    y = data.y, 
                                    raw_y = data.raw_seq[:,1], 
                                    datetime = data.datetime,
                                    window = params['window'],
                                    batch_size = params['batch_size'])

    labels = ['Actual', 'Training', 'Validation', 'Test']
    predictions.plot_predictions(title="SH300IF (LSTM model)", labels=labels)
    return predictions
# Out:
# C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\src\data\2010.4.1-2012.12.31.txt
# C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\src\data\2013.1.4-2014.12.31.txt
# C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\src\data\2015-2017.txt
# C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\src\data\2017-2019.4.29.txt

# %%
# Optimized window steps
# The ratio of time_steps and forecast_steps
windows = [
    (12,6,12)
]
RNN_pred_lst = []
GRU_pred_lst = []
LSTM_pred_lst = []

for window in windows:
    print(f"Window: time step = {window[0]}, forecast step = {window[1]}, window = {window[2]}")
    RNN_params['time_steps'] = window[0]
    RNN_params['forecast_steps'] = window[1]
    RNN_params['window'] = window[2]
    RNN_pred_lst.append(trainRNN(datasets_path[0], RNN_params))

    GRU_params['time_steps'] = window[0]
    GRU_params['forecast_steps'] = window[1]
    GRU_params['window'] = window[2]
    GRU_pred_lst.append(trainGRU(datasets_path[0], GRU_params))

    LSTM_params['time_steps'] = window[0]
    LSTM_params['forecast_steps'] = window[1]
    LSTM_params['window'] = window[2]
    LSTM_pred_lst.append(trainLSTM(datasets_path[0], LSTM_params))
    print("------------------------------------------------------------------------------------------------------")
    print()
# Out:
# Window: time step = 12, forecast step = 6, window = 12
# Loading dataset... Ready for training.
# Stock Index Code: SH300IF
# Train Set Length: 26048
# Validation Set Length: 2880
# Test Set Length: 3200
# Epoch 1/120
#
# Epoch 1: val_loss improved from inf to 0.03588, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 3s - 3ms/step - loss: 0.0819 - mda: 0.5238 - rmse: 0.2230 - val_loss: 0.0359 - val_mda: 0.6048 - val_rmse: 0.1649 - learning_rate: 1.0000e-04
# Epoch 2/120
#
# Epoch 2: val_loss improved from 0.03588 to 0.01442, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 1ms/step - loss: 0.0265 - mda: 0.5371 - rmse: 0.1465 - val_loss: 0.0144 - val_mda: 0.6068 - val_rmse: 0.1075 - learning_rate: 1.0000e-04
# Epoch 3/120
#
# Epoch 3: val_loss improved from 0.01442 to 0.01338, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 1ms/step - loss: 0.0177 - mda: 0.5458 - rmse: 0.1228 - val_loss: 0.0134 - val_mda: 0.6012 - val_rmse: 0.1058 - learning_rate: 1.0000e-04
# Epoch 4/120
#
# Epoch 4: val_loss improved from 0.01338 to 0.00812, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0144 - mda: 0.5502 - rmse: 0.1123 - val_loss: 0.0081 - val_mda: 0.6037 - val_rmse: 0.0839 - learning_rate: 1.0000e-04
# Epoch 5/120
#
# Epoch 5: val_loss improved from 0.00812 to 0.00365, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 1ms/step - loss: 0.0121 - mda: 0.5530 - rmse: 0.1037 - val_loss: 0.0037 - val_mda: 0.6068 - val_rmse: 0.0565 - learning_rate: 1.0000e-04
# Epoch 6/120
#
# Epoch 6: val_loss did not improve from 0.00365
# 814/814 - 1s - 1ms/step - loss: 0.0112 - mda: 0.5521 - rmse: 0.1007 - val_loss: 0.0059 - val_mda: 0.6109 - val_rmse: 0.0739 - learning_rate: 1.0000e-04
# Epoch 7/120
#
# Epoch 7: val_loss did not improve from 0.00365
# 814/814 - 1s - 1ms/step - loss: 0.0103 - mda: 0.5611 - rmse: 0.0969 - val_loss: 0.0069 - val_mda: 0.6103 - val_rmse: 0.0800 - learning_rate: 1.0000e-04
# Epoch 8/120
#
# Epoch 8: val_loss improved from 0.00365 to 0.00364, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0097 - mda: 0.5608 - rmse: 0.0940 - val_loss: 0.0036 - val_mda: 0.6119 - val_rmse: 0.0594 - learning_rate: 1.0000e-04
# Epoch 9/120
#
# Epoch 9: val_loss did not improve from 0.00364
# 814/814 - 1s - 2ms/step - loss: 0.0094 - mda: 0.5653 - rmse: 0.0931 - val_loss: 0.0040 - val_mda: 0.6107 - val_rmse: 0.0627 - learning_rate: 1.0000e-04
# Epoch 10/120
#
# Epoch 10: val_loss improved from 0.00364 to 0.00217, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0090 - mda: 0.5609 - rmse: 0.0913 - val_loss: 0.0022 - val_mda: 0.6116 - val_rmse: 0.0472 - learning_rate: 1.0000e-04
# Epoch 11/120
#
# Epoch 11: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0088 - mda: 0.5654 - rmse: 0.0905 - val_loss: 0.0049 - val_mda: 0.6119 - val_rmse: 0.0696 - learning_rate: 1.0000e-04
# Epoch 12/120
#
# Epoch 12: val_loss did not improve from 0.00217
# 814/814 - 1s - 1ms/step - loss: 0.0087 - mda: 0.5662 - rmse: 0.0906 - val_loss: 0.0039 - val_mda: 0.6132 - val_rmse: 0.0622 - learning_rate: 1.0000e-04
# Epoch 13/120
#
# Epoch 13: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0085 - mda: 0.5677 - rmse: 0.0897 - val_loss: 0.0046 - val_mda: 0.6137 - val_rmse: 0.0671 - learning_rate: 1.0000e-04
# Epoch 14/120
#
# Epoch 14: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0084 - mda: 0.5660 - rmse: 0.0891 - val_loss: 0.0040 - val_mda: 0.6129 - val_rmse: 0.0630 - learning_rate: 1.0000e-04
# Epoch 15/120
#
# Epoch 15: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0082 - mda: 0.5651 - rmse: 0.0882 - val_loss: 0.0040 - val_mda: 0.6138 - val_rmse: 0.0623 - learning_rate: 1.0000e-04
# Epoch 16/120
#
# Epoch 16: val_loss did not improve from 0.00217
# 814/814 - 1s - 1ms/step - loss: 0.0079 - mda: 0.5645 - rmse: 0.0869 - val_loss: 0.0043 - val_mda: 0.6147 - val_rmse: 0.0643 - learning_rate: 1.0000e-04
# Epoch 17/120
#
# Epoch 17: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0079 - mda: 0.5675 - rmse: 0.0870 - val_loss: 0.0046 - val_mda: 0.6169 - val_rmse: 0.0659 - learning_rate: 1.0000e-04
# Epoch 18/120
#
# Epoch 18: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0077 - mda: 0.5660 - rmse: 0.0865 - val_loss: 0.0042 - val_mda: 0.6153 - val_rmse: 0.0632 - learning_rate: 1.0000e-04
# Epoch 19/120
#
# Epoch 19: val_loss did not improve from 0.00217
# 814/814 - 1s - 1ms/step - loss: 0.0075 - mda: 0.5673 - rmse: 0.0856 - val_loss: 0.0062 - val_mda: 0.6146 - val_rmse: 0.0759 - learning_rate: 1.0000e-04
# Epoch 20/120
#
# Epoch 20: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0075 - mda: 0.5672 - rmse: 0.0851 - val_loss: 0.0068 - val_mda: 0.6137 - val_rmse: 0.0799 - learning_rate: 1.0000e-04
# Epoch 21/120
#
# Epoch 21: val_loss did not improve from 0.00217
# 814/814 - 1s - 1ms/step - loss: 0.0091 - mda: 0.5739 - rmse: 0.0915 - val_loss: 0.0090 - val_mda: 0.6136 - val_rmse: 0.0927 - learning_rate: 1.0000e-05
# Epoch 22/120
#
# Epoch 22: val_loss did not improve from 0.00217
# 814/814 - 1s - 1ms/step - loss: 0.0075 - mda: 0.5700 - rmse: 0.0862 - val_loss: 0.0058 - val_mda: 0.6155 - val_rmse: 0.0756 - learning_rate: 1.0000e-05
# Epoch 23/120
#
# Epoch 23: val_loss did not improve from 0.00217
# 814/814 - 1s - 1ms/step - loss: 0.0073 - mda: 0.5705 - rmse: 0.0851 - val_loss: 0.0044 - val_mda: 0.6141 - val_rmse: 0.0665 - learning_rate: 1.0000e-05
# Epoch 24/120
#
# Epoch 24: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0072 - mda: 0.5712 - rmse: 0.0842 - val_loss: 0.0034 - val_mda: 0.6124 - val_rmse: 0.0594 - learning_rate: 1.0000e-05
# Epoch 25/120
#
# Epoch 25: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0069 - mda: 0.5704 - rmse: 0.0836 - val_loss: 0.0030 - val_mda: 0.6118 - val_rmse: 0.0566 - learning_rate: 1.0000e-05
# Epoch 26/120
#
# Epoch 26: val_loss did not improve from 0.00217
# 814/814 - 1s - 2ms/step - loss: 0.0070 - mda: 0.5736 - rmse: 0.0838 - val_loss: 0.0025 - val_mda: 0.6126 - val_rmse: 0.0520 - learning_rate: 1.0000e-05
# Epoch 27/120
#
# Epoch 27: val_loss did not improve from 0.00217
# 814/814 - 1s - 1ms/step - loss: 0.0069 - mda: 0.5694 - rmse: 0.0834 - val_loss: 0.0023 - val_mda: 0.6118 - val_rmse: 0.0502 - learning_rate: 1.0000e-05
# Epoch 28/120
#
# Epoch 28: val_loss improved from 0.00217 to 0.00215, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0070 - mda: 0.5711 - rmse: 0.0834 - val_loss: 0.0022 - val_mda: 0.6114 - val_rmse: 0.0487 - learning_rate: 1.0000e-05
# Epoch 29/120
#
# Epoch 29: val_loss did not improve from 0.00215
# 814/814 - 1s - 2ms/step - loss: 0.0069 - mda: 0.5700 - rmse: 0.0827 - val_loss: 0.0022 - val_mda: 0.6119 - val_rmse: 0.0495 - learning_rate: 1.0000e-05
# Epoch 30/120
#
# Epoch 30: val_loss improved from 0.00215 to 0.00204, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0069 - mda: 0.5718 - rmse: 0.0829 - val_loss: 0.0020 - val_mda: 0.6117 - val_rmse: 0.0476 - learning_rate: 1.0000e-05
# Epoch 31/120
#
# Epoch 31: val_loss did not improve from 0.00204
# 814/814 - 1s - 2ms/step - loss: 0.0066 - mda: 0.5713 - rmse: 0.0822 - val_loss: 0.0021 - val_mda: 0.6131 - val_rmse: 0.0485 - learning_rate: 1.0000e-05
# Epoch 32/120
#
# Epoch 32: val_loss did not improve from 0.00204
# 814/814 - 1s - 2ms/step - loss: 0.0066 - mda: 0.5761 - rmse: 0.0821 - val_loss: 0.0021 - val_mda: 0.6122 - val_rmse: 0.0483 - learning_rate: 1.0000e-05
# Epoch 33/120
#
# Epoch 33: val_loss improved from 0.00204 to 0.00198, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 1ms/step - loss: 0.0067 - mda: 0.5720 - rmse: 0.0825 - val_loss: 0.0020 - val_mda: 0.6134 - val_rmse: 0.0470 - learning_rate: 1.0000e-05
# Epoch 34/120
#
# Epoch 34: val_loss improved from 0.00198 to 0.00197, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5722 - rmse: 0.0814 - val_loss: 0.0020 - val_mda: 0.6134 - val_rmse: 0.0469 - learning_rate: 1.0000e-05
# Epoch 35/120
#
# Epoch 35: val_loss improved from 0.00197 to 0.00166, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0066 - mda: 0.5730 - rmse: 0.0819 - val_loss: 0.0017 - val_mda: 0.6136 - val_rmse: 0.0436 - learning_rate: 1.0000e-05
# Epoch 36/120
#
# Epoch 36: val_loss did not improve from 0.00166
# 814/814 - 1s - 2ms/step - loss: 0.0067 - mda: 0.5740 - rmse: 0.0820 - val_loss: 0.0022 - val_mda: 0.6124 - val_rmse: 0.0491 - learning_rate: 1.0000e-05
# Epoch 37/120
#
# Epoch 37: val_loss improved from 0.00166 to 0.00159, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0066 - mda: 0.5720 - rmse: 0.0820 - val_loss: 0.0016 - val_mda: 0.6134 - val_rmse: 0.0429 - learning_rate: 1.0000e-05
# Epoch 38/120
#
# Epoch 38: val_loss did not improve from 0.00159
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5724 - rmse: 0.0812 - val_loss: 0.0019 - val_mda: 0.6118 - val_rmse: 0.0461 - learning_rate: 1.0000e-05
# Epoch 39/120
#
# Epoch 39: val_loss did not improve from 0.00159
# 814/814 - 2s - 2ms/step - loss: 0.0066 - mda: 0.5714 - rmse: 0.0818 - val_loss: 0.0018 - val_mda: 0.6131 - val_rmse: 0.0454 - learning_rate: 1.0000e-05
# Epoch 40/120
#
# Epoch 40: val_loss did not improve from 0.00159
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5745 - rmse: 0.0815 - val_loss: 0.0017 - val_mda: 0.6133 - val_rmse: 0.0439 - learning_rate: 1.0000e-05
# Epoch 41/120
#
# Epoch 41: val_loss improved from 0.00159 to 0.00158, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5704 - rmse: 0.0813 - val_loss: 0.0016 - val_mda: 0.6135 - val_rmse: 0.0428 - learning_rate: 1.0000e-05
# Epoch 42/120
#
# Epoch 42: val_loss did not improve from 0.00158
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5746 - rmse: 0.0810 - val_loss: 0.0018 - val_mda: 0.6141 - val_rmse: 0.0451 - learning_rate: 1.0000e-05
# Epoch 43/120
#
# Epoch 43: val_loss did not improve from 0.00158
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5738 - rmse: 0.0813 - val_loss: 0.0017 - val_mda: 0.6127 - val_rmse: 0.0440 - learning_rate: 1.0000e-05
# Epoch 44/120
#
# Epoch 44: val_loss did not improve from 0.00158
# 814/814 - 1s - 2ms/step - loss: 0.0066 - mda: 0.5745 - rmse: 0.0814 - val_loss: 0.0017 - val_mda: 0.6141 - val_rmse: 0.0444 - learning_rate: 1.0000e-05
# Epoch 45/120
#
# Epoch 45: val_loss did not improve from 0.00158
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5753 - rmse: 0.0815 - val_loss: 0.0020 - val_mda: 0.6134 - val_rmse: 0.0470 - learning_rate: 1.0000e-05
# Epoch 46/120
#
# Epoch 46: val_loss improved from 0.00158 to 0.00147, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0066 - mda: 0.5754 - rmse: 0.0813 - val_loss: 0.0015 - val_mda: 0.6139 - val_rmse: 0.0415 - learning_rate: 1.0000e-06
# Epoch 47/120
#
# Epoch 47: val_loss improved from 0.00147 to 0.00135, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5722 - rmse: 0.0808 - val_loss: 0.0014 - val_mda: 0.6140 - val_rmse: 0.0401 - learning_rate: 1.0000e-06
# Epoch 48/120
#
# Epoch 48: val_loss did not improve from 0.00135
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5724 - rmse: 0.0815 - val_loss: 0.0015 - val_mda: 0.6140 - val_rmse: 0.0415 - learning_rate: 1.0000e-06
# Epoch 49/120
#
# Epoch 49: val_loss improved from 0.00135 to 0.00131, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5748 - rmse: 0.0813 - val_loss: 0.0013 - val_mda: 0.6141 - val_rmse: 0.0395 - learning_rate: 1.0000e-06
# Epoch 50/120
#
# Epoch 50: val_loss did not improve from 0.00131
# 814/814 - 2s - 2ms/step - loss: 0.0065 - mda: 0.5758 - rmse: 0.0816 - val_loss: 0.0013 - val_mda: 0.6145 - val_rmse: 0.0396 - learning_rate: 1.0000e-06
# Epoch 51/120
#
# Epoch 51: val_loss improved from 0.00131 to 0.00124, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0065 - mda: 0.5745 - rmse: 0.0815 - val_loss: 0.0012 - val_mda: 0.6145 - val_rmse: 0.0387 - learning_rate: 1.0000e-06
# Epoch 52/120
#
# Epoch 52: val_loss improved from 0.00124 to 0.00114, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5676 - rmse: 0.0810 - val_loss: 0.0011 - val_mda: 0.6145 - val_rmse: 0.0374 - learning_rate: 1.0000e-06
# Epoch 53/120
#
# Epoch 53: val_loss improved from 0.00114 to 0.00108, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5742 - rmse: 0.0817 - val_loss: 0.0011 - val_mda: 0.6145 - val_rmse: 0.0365 - learning_rate: 1.0000e-06
# Epoch 54/120
#
# Epoch 54: val_loss did not improve from 0.00108
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5752 - rmse: 0.0814 - val_loss: 0.0011 - val_mda: 0.6142 - val_rmse: 0.0367 - learning_rate: 1.0000e-06
# Epoch 55/120
#
# Epoch 55: val_loss improved from 0.00108 to 0.00103, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5742 - rmse: 0.0808 - val_loss: 0.0010 - val_mda: 0.6146 - val_rmse: 0.0358 - learning_rate: 1.0000e-06
# Epoch 56/120
#
# Epoch 56: val_loss did not improve from 0.00103
# 814/814 - 1s - 2ms/step - loss: 0.0066 - mda: 0.5745 - rmse: 0.0817 - val_loss: 0.0010 - val_mda: 0.6145 - val_rmse: 0.0360 - learning_rate: 1.0000e-06
# Epoch 57/120
#
# Epoch 57: val_loss did not improve from 0.00103
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5754 - rmse: 0.0813 - val_loss: 0.0010 - val_mda: 0.6145 - val_rmse: 0.0360 - learning_rate: 1.0000e-06
# Epoch 58/120
#
# Epoch 58: val_loss did not improve from 0.00103
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5745 - rmse: 0.0816 - val_loss: 0.0011 - val_mda: 0.6138 - val_rmse: 0.0363 - learning_rate: 1.0000e-06
# Epoch 59/120
#
# Epoch 59: val_loss did not improve from 0.00103
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5736 - rmse: 0.0810 - val_loss: 0.0011 - val_mda: 0.6144 - val_rmse: 0.0363 - learning_rate: 1.0000e-06
# Epoch 60/120
#
# Epoch 60: val_loss improved from 0.00103 to 0.00099, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5730 - rmse: 0.0809 - val_loss: 9.8629e-04 - val_mda: 0.6147 - val_rmse: 0.0352 - learning_rate: 1.0000e-06
# Epoch 61/120
#
# Epoch 61: val_loss did not improve from 0.00099
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5746 - rmse: 0.0814 - val_loss: 0.0010 - val_mda: 0.6148 - val_rmse: 0.0357 - learning_rate: 1.0000e-06
# Epoch 62/120
#
# Epoch 62: val_loss did not improve from 0.00099
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5733 - rmse: 0.0810 - val_loss: 0.0010 - val_mda: 0.6143 - val_rmse: 0.0357 - learning_rate: 1.0000e-06
# Epoch 63/120
#
# Epoch 63: val_loss improved from 0.00099 to 0.00098, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0066 - mda: 0.5740 - rmse: 0.0817 - val_loss: 9.8117e-04 - val_mda: 0.6143 - val_rmse: 0.0352 - learning_rate: 1.0000e-06
# Epoch 64/120
#
# Epoch 64: val_loss improved from 0.00098 to 0.00097, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0063 - mda: 0.5752 - rmse: 0.0807 - val_loss: 9.7412e-04 - val_mda: 0.6143 - val_rmse: 0.0351 - learning_rate: 1.0000e-07
# Epoch 65/120
#
# Epoch 65: val_loss improved from 0.00097 to 0.00097, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5748 - rmse: 0.0811 - val_loss: 9.6555e-04 - val_mda: 0.6143 - val_rmse: 0.0349 - learning_rate: 1.0000e-07
# Epoch 66/120
#
# Epoch 66: val_loss did not improve from 0.00097
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5737 - rmse: 0.0809 - val_loss: 9.6711e-04 - val_mda: 0.6146 - val_rmse: 0.0350 - learning_rate: 1.0000e-07
# Epoch 67/120
#
# Epoch 67: val_loss improved from 0.00097 to 0.00096, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0063 - mda: 0.5738 - rmse: 0.0806 - val_loss: 9.5629e-04 - val_mda: 0.6146 - val_rmse: 0.0348 - learning_rate: 1.0000e-07
# Epoch 68/120
#
# Epoch 68: val_loss did not improve from 0.00096
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5712 - rmse: 0.0813 - val_loss: 9.5730e-04 - val_mda: 0.6146 - val_rmse: 0.0348 - learning_rate: 1.0000e-07
# Epoch 69/120
#
# Epoch 69: val_loss improved from 0.00096 to 0.00096, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5738 - rmse: 0.0815 - val_loss: 9.5599e-04 - val_mda: 0.6146 - val_rmse: 0.0348 - learning_rate: 1.0000e-07
# Epoch 70/120
#
# Epoch 70: val_loss did not improve from 0.00096
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5740 - rmse: 0.0809 - val_loss: 9.6143e-04 - val_mda: 0.6146 - val_rmse: 0.0349 - learning_rate: 1.0000e-07
# Epoch 71/120
#
# Epoch 71: val_loss improved from 0.00096 to 0.00095, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5728 - rmse: 0.0808 - val_loss: 9.5466e-04 - val_mda: 0.6146 - val_rmse: 0.0348 - learning_rate: 1.0000e-07
# Epoch 72/120
#
# Epoch 72: val_loss did not improve from 0.00095
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5723 - rmse: 0.0812 - val_loss: 9.5559e-04 - val_mda: 0.6146 - val_rmse: 0.0348 - learning_rate: 1.0000e-07
# Epoch 73/120
#
# Epoch 73: val_loss did not improve from 0.00095
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5740 - rmse: 0.0813 - val_loss: 9.6318e-04 - val_mda: 0.6146 - val_rmse: 0.0349 - learning_rate: 1.0000e-07
# Epoch 74/120
#
# Epoch 74: val_loss did not improve from 0.00095
# 814/814 - 1s - 1ms/step - loss: 0.0065 - mda: 0.5757 - rmse: 0.0811 - val_loss: 9.5515e-04 - val_mda: 0.6146 - val_rmse: 0.0348 - learning_rate: 1.0000e-07
# Epoch 75/120
#
# Epoch 75: val_loss improved from 0.00095 to 0.00095, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5720 - rmse: 0.0808 - val_loss: 9.5418e-04 - val_mda: 0.6146 - val_rmse: 0.0348 - learning_rate: 1.0000e-08
# Epoch 76/120
#
# Epoch 76: val_loss improved from 0.00095 to 0.00095, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5719 - rmse: 0.0813 - val_loss: 9.5153e-04 - val_mda: 0.6146 - val_rmse: 0.0347 - learning_rate: 1.0000e-08
# Epoch 77/120
#
# Epoch 77: val_loss did not improve from 0.00095
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5745 - rmse: 0.0816 - val_loss: 9.5179e-04 - val_mda: 0.6146 - val_rmse: 0.0347 - learning_rate: 1.0000e-08
# Epoch 78/120
#
# Epoch 78: val_loss improved from 0.00095 to 0.00095, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0063 - mda: 0.5740 - rmse: 0.0804 - val_loss: 9.5005e-04 - val_mda: 0.6146 - val_rmse: 0.0347 - learning_rate: 1.0000e-08
# Epoch 79/120
#
# Epoch 79: val_loss improved from 0.00095 to 0.00095, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5721 - rmse: 0.0809 - val_loss: 9.4828e-04 - val_mda: 0.6146 - val_rmse: 0.0347 - learning_rate: 1.0000e-08
# Epoch 80/120
#
# Epoch 80: val_loss improved from 0.00095 to 0.00095, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5710 - rmse: 0.0806 - val_loss: 9.4706e-04 - val_mda: 0.6146 - val_rmse: 0.0347 - learning_rate: 1.0000e-08
# Epoch 81/120
#
# Epoch 81: val_loss improved from 0.00095 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5750 - rmse: 0.0809 - val_loss: 9.4492e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-08
# Epoch 82/120
#
# Epoch 82: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5745 - rmse: 0.0811 - val_loss: 9.4341e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-08
# Epoch 83/120
#
# Epoch 83: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0065 - mda: 0.5730 - rmse: 0.0815 - val_loss: 9.4273e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-08
# Epoch 84/120
#
# Epoch 84: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5763 - rmse: 0.0810 - val_loss: 9.4137e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-08
# Epoch 85/120
#
# Epoch 85: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0065 - mda: 0.5731 - rmse: 0.0810 - val_loss: 9.4134e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 86/120
#
# Epoch 86: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5744 - rmse: 0.0810 - val_loss: 9.4125e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 87/120
#
# Epoch 87: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0066 - mda: 0.5729 - rmse: 0.0818 - val_loss: 9.4118e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 88/120
#
# Epoch 88: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0063 - mda: 0.5716 - rmse: 0.0804 - val_loss: 9.4108e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 89/120
#
# Epoch 89: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 3ms/step - loss: 0.0064 - mda: 0.5745 - rmse: 0.0812 - val_loss: 9.4104e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 90/120
#
# Epoch 90: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5728 - rmse: 0.0814 - val_loss: 9.4096e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 91/120
#
# Epoch 91: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5715 - rmse: 0.0810 - val_loss: 9.4090e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 92/120
#
# Epoch 92: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 3ms/step - loss: 0.0064 - mda: 0.5713 - rmse: 0.0809 - val_loss: 9.4086e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 93/120
#
# Epoch 93: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0065 - mda: 0.5758 - rmse: 0.0812 - val_loss: 9.4081e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 94/120
#
# Epoch 94: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0065 - mda: 0.5745 - rmse: 0.0813 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-09
# Epoch 95/120
#
# Epoch 95: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 3ms/step - loss: 0.0065 - mda: 0.5755 - rmse: 0.0812 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 96/120
#
# Epoch 96: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5737 - rmse: 0.0813 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 97/120
#
# Epoch 97: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 3ms/step - loss: 0.0064 - mda: 0.5736 - rmse: 0.0812 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 98/120
#
# Epoch 98: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 3ms/step - loss: 0.0065 - mda: 0.5722 - rmse: 0.0813 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 99/120
#
# Epoch 99: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 3ms/step - loss: 0.0064 - mda: 0.5730 - rmse: 0.0810 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 100/120
#
# Epoch 100: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0065 - mda: 0.5733 - rmse: 0.0812 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 101/120
#
# Epoch 101: val_loss did not improve from 0.00094
# 814/814 - 2s - 2ms/step - loss: 0.0065 - mda: 0.5751 - rmse: 0.0815 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 102/120
#
# Epoch 102: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0066 - mda: 0.5721 - rmse: 0.0816 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 103/120
#
# Epoch 103: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0063 - mda: 0.5743 - rmse: 0.0810 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 104/120
#
# Epoch 104: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5715 - rmse: 0.0808 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-10
# Epoch 105/120
#
# Epoch 105: val_loss did not improve from 0.00094
# 814/814 - 2s - 3ms/step - loss: 0.0064 - mda: 0.5748 - rmse: 0.0812 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 106/120
#
# Epoch 106: val_loss did not improve from 0.00094
# 814/814 - 2s - 3ms/step - loss: 0.0064 - mda: 0.5731 - rmse: 0.0812 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 107/120
#
# Epoch 107: val_loss did not improve from 0.00094
# 814/814 - 4s - 4ms/step - loss: 0.0064 - mda: 0.5721 - rmse: 0.0810 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 108/120
#
# Epoch 108: val_loss improved from 0.00094 to 0.00094, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\RNN_bestweights.keras
# 814/814 - 2s - 3ms/step - loss: 0.0064 - mda: 0.5749 - rmse: 0.0812 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 109/120
#
# Epoch 109: val_loss did not improve from 0.00094
# 814/814 - 2s - 3ms/step - loss: 0.0064 - mda: 0.5731 - rmse: 0.0811 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 110/120
#
# Epoch 110: val_loss did not improve from 0.00094
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5713 - rmse: 0.0813 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 111/120
#
# Epoch 111: val_loss did not improve from 0.00094
# 814/814 - 2s - 2ms/step - loss: 0.0065 - mda: 0.5730 - rmse: 0.0812 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 112/120
#
# Epoch 112: val_loss did not improve from 0.00094
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5742 - rmse: 0.0810 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 113/120
#
# Epoch 113: val_loss did not improve from 0.00094
# 814/814 - 1s - 2ms/step - loss: 0.0066 - mda: 0.5724 - rmse: 0.0818 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 114/120
#
# Epoch 114: val_loss did not improve from 0.00094
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5735 - rmse: 0.0806 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-11
# Epoch 115/120
#
# Epoch 115: val_loss did not improve from 0.00094
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5705 - rmse: 0.0809 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-12
# Epoch 116/120
#
# Epoch 116: val_loss did not improve from 0.00094
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5731 - rmse: 0.0814 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-12
# Epoch 117/120
#
# Epoch 117: val_loss did not improve from 0.00094
# 814/814 - 2s - 2ms/step - loss: 0.0064 - mda: 0.5751 - rmse: 0.0809 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-12
# Epoch 118/120
#
# Epoch 118: val_loss did not improve from 0.00094
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5748 - rmse: 0.0816 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-12
# Epoch 119/120
#
# Epoch 119: val_loss did not improve from 0.00094
# 814/814 - 1s - 2ms/step - loss: 0.0065 - mda: 0.5712 - rmse: 0.0811 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-12
# Epoch 120/120
#
# Epoch 120: val_loss did not improve from 0.00094
# 814/814 - 1s - 2ms/step - loss: 0.0064 - mda: 0.5699 - rmse: 0.0808 - val_loss: 9.4078e-04 - val_mda: 0.6146 - val_rmse: 0.0346 - learning_rate: 1.0000e-12
# DataFrame preview:
#        loss       mda      rmse  val_loss   val_mda  val_rmse  learning_rate
# 0  0.081872  0.523833  0.223021  0.035877  0.604833  0.164933         0.0001
# 1  0.026495  0.537150  0.146452  0.014421  0.606833  0.107456         0.0001
# 2  0.017672  0.545842  0.122817  0.013375  0.601222  0.105800         0.0001
# 3  0.014399  0.550234  0.112304  0.008123  0.603722  0.083863         0.0001
# 4  0.012104  0.553050  0.103710  0.003651  0.606833  0.056465         0.0001
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# Loading dataset... Ready for training.
# Epoch 1/120
#
# Epoch 1: val_loss improved from inf to 0.03486, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\GRU_bestweights.keras
# 814/814 - 10s - 12ms/step - loss: 0.1145 - mda: 0.5288 - rmse: 0.2191 - val_loss: 0.0349 - val_mda: 0.6068 - val_rmse: 0.1779 - learning_rate: 1.0000e-04
# Epoch 2/120
#
# Epoch 2: val_loss improved from 0.03486 to 0.00640, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\GRU_bestweights.keras
# 814/814 - 5s - 6ms/step - loss: 0.0174 - mda: 0.5392 - rmse: 0.1190 - val_loss: 0.0064 - val_mda: 0.6059 - val_rmse: 0.0772 - learning_rate: 1.0000e-04
# Epoch 3/120
#
# Epoch 3: val_loss improved from 0.00640 to 0.00275, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\GRU_bestweights.keras
# 814/814 - 3s - 3ms/step - loss: 0.0131 - mda: 0.5495 - rmse: 0.1060 - val_loss: 0.0028 - val_mda: 0.6085 - val_rmse: 0.0523 - learning_rate: 1.0000e-04
# Epoch 4/120
#
# Epoch 4: val_loss improved from 0.00275 to 0.00150, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\GRU_bestweights.keras
# 814/814 - 3s - 3ms/step - loss: 0.0113 - mda: 0.5565 - rmse: 0.0994 - val_loss: 0.0015 - val_mda: 0.6092 - val_rmse: 0.0399 - learning_rate: 1.0000e-04
# Epoch 5/120
#
# Epoch 5: val_loss improved from 0.00150 to 0.00127, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\GRU_bestweights.keras
# 814/814 - 3s - 3ms/step - loss: 0.0105 - mda: 0.5568 - rmse: 0.0958 - val_loss: 0.0013 - val_mda: 0.6084 - val_rmse: 0.0375 - learning_rate: 1.0000e-04
# Epoch 6/120
#
# Epoch 6: val_loss did not improve from 0.00127
# 814/814 - 3s - 3ms/step - loss: 0.0103 - mda: 0.5590 - rmse: 0.0949 - val_loss: 0.0017 - val_mda: 0.6089 - val_rmse: 0.0426 - learning_rate: 1.0000e-04
# Epoch 7/120
#
# Epoch 7: val_loss did not improve from 0.00127
# 814/814 - 3s - 3ms/step - loss: 0.0096 - mda: 0.5631 - rmse: 0.0920 - val_loss: 0.0028 - val_mda: 0.6090 - val_rmse: 0.0538 - learning_rate: 1.0000e-04
# Epoch 8/120
#
# Epoch 8: val_loss did not improve from 0.00127
# 814/814 - 3s - 3ms/step - loss: 0.0095 - mda: 0.5606 - rmse: 0.0915 - val_loss: 0.0025 - val_mda: 0.6090 - val_rmse: 0.0509 - learning_rate: 1.0000e-04
# Epoch 9/120
#
# Epoch 9: val_loss did not improve from 0.00127
# 814/814 - 3s - 3ms/step - loss: 0.0091 - mda: 0.5635 - rmse: 0.0895 - val_loss: 0.0025 - val_mda: 0.6087 - val_rmse: 0.0514 - learning_rate: 1.0000e-04
# Epoch 10/120
#
# Epoch 10: val_loss did not improve from 0.00127
# 814/814 - 3s - 3ms/step - loss: 0.0088 - mda: 0.5679 - rmse: 0.0891 - val_loss: 0.0028 - val_mda: 0.6103 - val_rmse: 0.0529 - learning_rate: 1.0000e-04
# Epoch 11/120
#
# Epoch 11: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0085 - mda: 0.5674 - rmse: 0.0878 - val_loss: 0.0029 - val_mda: 0.6121 - val_rmse: 0.0543 - learning_rate: 1.0000e-04
# Epoch 12/120
#
# Epoch 12: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0083 - mda: 0.5686 - rmse: 0.0871 - val_loss: 0.0040 - val_mda: 0.6132 - val_rmse: 0.0630 - learning_rate: 1.0000e-04
# Epoch 13/120
#
# Epoch 13: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0083 - mda: 0.5683 - rmse: 0.0868 - val_loss: 0.0037 - val_mda: 0.6136 - val_rmse: 0.0596 - learning_rate: 1.0000e-04
# Epoch 14/120
#
# Epoch 14: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0081 - mda: 0.5653 - rmse: 0.0859 - val_loss: 0.0057 - val_mda: 0.6142 - val_rmse: 0.0732 - learning_rate: 1.0000e-04
# Epoch 15/120
#
# Epoch 15: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0079 - mda: 0.5700 - rmse: 0.0851 - val_loss: 0.0066 - val_mda: 0.6144 - val_rmse: 0.0777 - learning_rate: 1.0000e-04
# Epoch 16/120
#
# Epoch 16: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0088 - mda: 0.5714 - rmse: 0.0891 - val_loss: 0.0100 - val_mda: 0.6148 - val_rmse: 0.0977 - learning_rate: 1.0000e-05
# Epoch 17/120
#
# Epoch 17: val_loss did not improve from 0.00127
# 814/814 - 4s - 4ms/step - loss: 0.0072 - mda: 0.5691 - rmse: 0.0840 - val_loss: 0.0081 - val_mda: 0.6147 - val_rmse: 0.0881 - learning_rate: 1.0000e-05
# Epoch 18/120
#
# Epoch 18: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0070 - mda: 0.5698 - rmse: 0.0829 - val_loss: 0.0074 - val_mda: 0.6147 - val_rmse: 0.0846 - learning_rate: 1.0000e-05
# Epoch 19/120
#
# Epoch 19: val_loss did not improve from 0.00127
# 814/814 - 7s - 9ms/step - loss: 0.0069 - mda: 0.5690 - rmse: 0.0823 - val_loss: 0.0063 - val_mda: 0.6147 - val_rmse: 0.0785 - learning_rate: 1.0000e-05
# Epoch 20/120
#
# Epoch 20: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0068 - mda: 0.5703 - rmse: 0.0819 - val_loss: 0.0057 - val_mda: 0.6145 - val_rmse: 0.0747 - learning_rate: 1.0000e-05
# Epoch 21/120
#
# Epoch 21: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0068 - mda: 0.5686 - rmse: 0.0818 - val_loss: 0.0052 - val_mda: 0.6144 - val_rmse: 0.0714 - learning_rate: 1.0000e-05
# Epoch 22/120
#
# Epoch 22: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0067 - mda: 0.5727 - rmse: 0.0816 - val_loss: 0.0055 - val_mda: 0.6144 - val_rmse: 0.0738 - learning_rate: 1.0000e-05
# Epoch 23/120
#
# Epoch 23: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0065 - mda: 0.5726 - rmse: 0.0809 - val_loss: 0.0050 - val_mda: 0.6141 - val_rmse: 0.0703 - learning_rate: 1.0000e-05
# Epoch 24/120
#
# Epoch 24: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0065 - mda: 0.5730 - rmse: 0.0807 - val_loss: 0.0050 - val_mda: 0.6143 - val_rmse: 0.0703 - learning_rate: 1.0000e-05
# Epoch 25/120
#
# Epoch 25: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0067 - mda: 0.5691 - rmse: 0.0814 - val_loss: 0.0051 - val_mda: 0.6143 - val_rmse: 0.0709 - learning_rate: 1.0000e-05
# Epoch 26/120
#
# Epoch 26: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0068 - mda: 0.5705 - rmse: 0.0820 - val_loss: 0.0035 - val_mda: 0.6143 - val_rmse: 0.0596 - learning_rate: 1.0000e-06
# Epoch 27/120
#
# Epoch 27: val_loss did not improve from 0.00127
# 814/814 - 4s - 4ms/step - loss: 0.0066 - mda: 0.5726 - rmse: 0.0813 - val_loss: 0.0032 - val_mda: 0.6143 - val_rmse: 0.0574 - learning_rate: 1.0000e-06
# Epoch 28/120
#
# Epoch 28: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0065 - mda: 0.5730 - rmse: 0.0806 - val_loss: 0.0032 - val_mda: 0.6143 - val_rmse: 0.0575 - learning_rate: 1.0000e-06
# Epoch 29/120
#
# Epoch 29: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0067 - mda: 0.5703 - rmse: 0.0813 - val_loss: 0.0031 - val_mda: 0.6143 - val_rmse: 0.0563 - learning_rate: 1.0000e-06
# Epoch 30/120
#
# Epoch 30: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0066 - mda: 0.5714 - rmse: 0.0813 - val_loss: 0.0029 - val_mda: 0.6142 - val_rmse: 0.0552 - learning_rate: 1.0000e-06
# Epoch 31/120
#
# Epoch 31: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0066 - mda: 0.5748 - rmse: 0.0810 - val_loss: 0.0030 - val_mda: 0.6142 - val_rmse: 0.0555 - learning_rate: 1.0000e-06
# Epoch 32/120
#
# Epoch 32: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0066 - mda: 0.5723 - rmse: 0.0814 - val_loss: 0.0029 - val_mda: 0.6142 - val_rmse: 0.0546 - learning_rate: 1.0000e-06
# Epoch 33/120
#
# Epoch 33: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0068 - mda: 0.5725 - rmse: 0.0816 - val_loss: 0.0030 - val_mda: 0.6142 - val_rmse: 0.0553 - learning_rate: 1.0000e-06
# Epoch 34/120
#
# Epoch 34: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0066 - mda: 0.5729 - rmse: 0.0811 - val_loss: 0.0029 - val_mda: 0.6142 - val_rmse: 0.0548 - learning_rate: 1.0000e-06
# Epoch 35/120
#
# Epoch 35: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0066 - mda: 0.5668 - rmse: 0.0812 - val_loss: 0.0027 - val_mda: 0.6142 - val_rmse: 0.0533 - learning_rate: 1.0000e-06
# Epoch 36/120
#
# Epoch 36: val_loss did not improve from 0.00127
# 814/814 - 4s - 4ms/step - loss: 0.0066 - mda: 0.5695 - rmse: 0.0807 - val_loss: 0.0027 - val_mda: 0.6142 - val_rmse: 0.0533 - learning_rate: 1.0000e-07
# Epoch 37/120
#
# Epoch 37: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0066 - mda: 0.5741 - rmse: 0.0812 - val_loss: 0.0027 - val_mda: 0.6142 - val_rmse: 0.0531 - learning_rate: 1.0000e-07
# Epoch 38/120
#
# Epoch 38: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0064 - mda: 0.5698 - rmse: 0.0804 - val_loss: 0.0027 - val_mda: 0.6142 - val_rmse: 0.0529 - learning_rate: 1.0000e-07
# Epoch 39/120
#
# Epoch 39: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0066 - mda: 0.5710 - rmse: 0.0809 - val_loss: 0.0027 - val_mda: 0.6142 - val_rmse: 0.0529 - learning_rate: 1.0000e-07
# Epoch 40/120
#
# Epoch 40: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0065 - mda: 0.5696 - rmse: 0.0806 - val_loss: 0.0027 - val_mda: 0.6142 - val_rmse: 0.0527 - learning_rate: 1.0000e-07
# Epoch 41/120
#
# Epoch 41: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0064 - mda: 0.5718 - rmse: 0.0804 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0524 - learning_rate: 1.0000e-07
# Epoch 42/120
#
# Epoch 42: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0064 - mda: 0.5733 - rmse: 0.0807 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0522 - learning_rate: 1.0000e-07
# Epoch 43/120
#
# Epoch 43: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0066 - mda: 0.5708 - rmse: 0.0809 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0521 - learning_rate: 1.0000e-07
# Epoch 44/120
#
# Epoch 44: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0066 - mda: 0.5671 - rmse: 0.0808 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0521 - learning_rate: 1.0000e-07
# Epoch 45/120
#
# Epoch 45: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0066 - mda: 0.5758 - rmse: 0.0812 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0522 - learning_rate: 1.0000e-07
# Epoch 46/120
#
# Epoch 46: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0065 - mda: 0.5718 - rmse: 0.0808 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0522 - learning_rate: 1.0000e-08
# Epoch 47/120
#
# Epoch 47: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0065 - mda: 0.5701 - rmse: 0.0804 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0522 - learning_rate: 1.0000e-08
# Epoch 48/120
#
# Epoch 48: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0065 - mda: 0.5678 - rmse: 0.0806 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0522 - learning_rate: 1.0000e-08
# Epoch 49/120
#
# Epoch 49: val_loss did not improve from 0.00127
# 814/814 - 5s - 6ms/step - loss: 0.0065 - mda: 0.5710 - rmse: 0.0805 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0522 - learning_rate: 1.0000e-08
# Epoch 50/120
#
# Epoch 50: val_loss did not improve from 0.00127
# 814/814 - 5s - 6ms/step - loss: 0.0064 - mda: 0.5727 - rmse: 0.0806 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0521 - learning_rate: 1.0000e-08
# Epoch 51/120
#
# Epoch 51: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0065 - mda: 0.5746 - rmse: 0.0806 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0521 - learning_rate: 1.0000e-08
# Epoch 52/120
#
# Epoch 52: val_loss did not improve from 0.00127
# 814/814 - 5s - 6ms/step - loss: 0.0065 - mda: 0.5736 - rmse: 0.0808 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0521 - learning_rate: 1.0000e-08
# Epoch 53/120
#
# Epoch 53: val_loss did not improve from 0.00127
# 814/814 - 5s - 6ms/step - loss: 0.0066 - mda: 0.5713 - rmse: 0.0813 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0521 - learning_rate: 1.0000e-08
# Epoch 54/120
#
# Epoch 54: val_loss did not improve from 0.00127
# 814/814 - 5s - 6ms/step - loss: 0.0066 - mda: 0.5704 - rmse: 0.0808 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0521 - learning_rate: 1.0000e-08
# Epoch 55/120
#
# Epoch 55: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0065 - mda: 0.5741 - rmse: 0.0809 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-08
# Epoch 56/120
#
# Epoch 56: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0065 - mda: 0.5691 - rmse: 0.0807 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 57/120
#
# Epoch 57: val_loss did not improve from 0.00127
# 814/814 - 4s - 6ms/step - loss: 0.0067 - mda: 0.5687 - rmse: 0.0813 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 58/120
#
# Epoch 58: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0064 - mda: 0.5710 - rmse: 0.0803 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 59/120
#
# Epoch 59: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0065 - mda: 0.5723 - rmse: 0.0809 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 60/120
#
# Epoch 60: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0066 - mda: 0.5673 - rmse: 0.0810 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 61/120
#
# Epoch 61: val_loss did not improve from 0.00127
# 814/814 - 4s - 5ms/step - loss: 0.0065 - mda: 0.5715 - rmse: 0.0808 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 62/120
#
# Epoch 62: val_loss did not improve from 0.00127
# 814/814 - 4s - 4ms/step - loss: 0.0066 - mda: 0.5731 - rmse: 0.0811 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 63/120
#
# Epoch 63: val_loss did not improve from 0.00127
# 814/814 - 4s - 4ms/step - loss: 0.0065 - mda: 0.5736 - rmse: 0.0807 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 64/120
#
# Epoch 64: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0065 - mda: 0.5722 - rmse: 0.0805 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 65/120
#
# Epoch 65: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0066 - mda: 0.5719 - rmse: 0.0809 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-09
# Epoch 66/120
#
# Epoch 66: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0065 - mda: 0.5712 - rmse: 0.0807 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-10
# Epoch 67/120
#
# Epoch 67: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0066 - mda: 0.5722 - rmse: 0.0806 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-10
# Epoch 68/120
#
# Epoch 68: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0067 - mda: 0.5677 - rmse: 0.0810 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-10
# Epoch 69/120
#
# Epoch 69: val_loss did not improve from 0.00127
# 814/814 - 3s - 4ms/step - loss: 0.0064 - mda: 0.5713 - rmse: 0.0806 - val_loss: 0.0026 - val_mda: 0.6142 - val_rmse: 0.0520 - learning_rate: 1.0000e-10
# Epoch 70/120
#
# ...
# Epoch 59/120
#
# Epoch 59: val_loss improved from 0.00472 to 0.00457, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5700 - rmse: 0.0792 - val_loss: 0.0046 - val_mda: 0.6051 - val_rmse: 0.0662 - learning_rate: 1.0000e-06
# Epoch 60/120
#
# Epoch 60: val_loss improved from 0.00457 to 0.00444, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0064 - mda: 0.5701 - rmse: 0.0795 - val_loss: 0.0044 - val_mda: 0.6051 - val_rmse: 0.0654 - learning_rate: 1.0000e-06
# Epoch 61/120
#
# Epoch 61: val_loss improved from 0.00444 to 0.00420, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5709 - rmse: 0.0789 - val_loss: 0.0042 - val_mda: 0.6053 - val_rmse: 0.0637 - learning_rate: 1.0000e-06
# Epoch 62/120
#
# Epoch 62: val_loss improved from 0.00420 to 0.00403, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5729 - rmse: 0.0793 - val_loss: 0.0040 - val_mda: 0.6053 - val_rmse: 0.0625 - learning_rate: 1.0000e-06
# Epoch 63/120
#
# Epoch 63: val_loss improved from 0.00403 to 0.00396, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5733 - rmse: 0.0789 - val_loss: 0.0040 - val_mda: 0.6053 - val_rmse: 0.0620 - learning_rate: 1.0000e-06
# Epoch 64/120
#
# Epoch 64: val_loss improved from 0.00396 to 0.00388, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5680 - rmse: 0.0794 - val_loss: 0.0039 - val_mda: 0.6049 - val_rmse: 0.0615 - learning_rate: 1.0000e-06
# Epoch 65/120
#
# Epoch 65: val_loss improved from 0.00388 to 0.00362, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5715 - rmse: 0.0793 - val_loss: 0.0036 - val_mda: 0.6049 - val_rmse: 0.0595 - learning_rate: 1.0000e-06
# Epoch 66/120
#
# Epoch 66: val_loss did not improve from 0.00362
# 814/814 - 4s - 4ms/step - loss: 0.0062 - mda: 0.5715 - rmse: 0.0788 - val_loss: 0.0037 - val_mda: 0.6049 - val_rmse: 0.0600 - learning_rate: 1.0000e-06
# Epoch 67/120
#
# Epoch 67: val_loss did not improve from 0.00362
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5704 - rmse: 0.0783 - val_loss: 0.0038 - val_mda: 0.6049 - val_rmse: 0.0612 - learning_rate: 1.0000e-06
# Epoch 68/120
#
# Epoch 68: val_loss did not improve from 0.00362
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5722 - rmse: 0.0788 - val_loss: 0.0037 - val_mda: 0.6049 - val_rmse: 0.0605 - learning_rate: 1.0000e-06
# Epoch 69/120
#
# Epoch 69: val_loss improved from 0.00362 to 0.00357, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 4s - 4ms/step - loss: 0.0063 - mda: 0.5701 - rmse: 0.0790 - val_loss: 0.0036 - val_mda: 0.6049 - val_rmse: 0.0592 - learning_rate: 1.0000e-06
# Epoch 70/120
#
# Epoch 70: val_loss improved from 0.00357 to 0.00356, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 4s - 4ms/step - loss: 0.0062 - mda: 0.5685 - rmse: 0.0788 - val_loss: 0.0036 - val_mda: 0.6049 - val_rmse: 0.0592 - learning_rate: 1.0000e-06
# Epoch 71/120
#
# Epoch 71: val_loss improved from 0.00356 to 0.00346, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 4s - 4ms/step - loss: 0.0063 - mda: 0.5685 - rmse: 0.0788 - val_loss: 0.0035 - val_mda: 0.6049 - val_rmse: 0.0584 - learning_rate: 1.0000e-06
# Epoch 72/120
#
# Epoch 72: val_loss did not improve from 0.00346
# 814/814 - 4s - 5ms/step - loss: 0.0061 - mda: 0.5726 - rmse: 0.0781 - val_loss: 0.0036 - val_mda: 0.6049 - val_rmse: 0.0594 - learning_rate: 1.0000e-06
# Epoch 73/120
#
# Epoch 73: val_loss improved from 0.00346 to 0.00345, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 4s - 4ms/step - loss: 0.0063 - mda: 0.5710 - rmse: 0.0788 - val_loss: 0.0034 - val_mda: 0.6053 - val_rmse: 0.0584 - learning_rate: 1.0000e-06
# Epoch 74/120
#
# Epoch 74: val_loss did not improve from 0.00345
# 814/814 - 4s - 5ms/step - loss: 0.0063 - mda: 0.5699 - rmse: 0.0789 - val_loss: 0.0035 - val_mda: 0.6053 - val_rmse: 0.0585 - learning_rate: 1.0000e-06
# Epoch 75/120
#
# Epoch 75: val_loss improved from 0.00345 to 0.00335, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 4s - 5ms/step - loss: 0.0063 - mda: 0.5717 - rmse: 0.0791 - val_loss: 0.0033 - val_mda: 0.6053 - val_rmse: 0.0576 - learning_rate: 1.0000e-06
# Epoch 76/120
#
# Epoch 76: val_loss did not improve from 0.00335
# 814/814 - 4s - 5ms/step - loss: 0.0063 - mda: 0.5682 - rmse: 0.0791 - val_loss: 0.0033 - val_mda: 0.6053 - val_rmse: 0.0576 - learning_rate: 1.0000e-06
# Epoch 77/120
#
# Epoch 77: val_loss improved from 0.00335 to 0.00318, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 4s - 5ms/step - loss: 0.0061 - mda: 0.5715 - rmse: 0.0782 - val_loss: 0.0032 - val_mda: 0.6053 - val_rmse: 0.0563 - learning_rate: 1.0000e-06
# Epoch 78/120
#
# Epoch 78: val_loss did not improve from 0.00318
# 814/814 - 4s - 5ms/step - loss: 0.0064 - mda: 0.5676 - rmse: 0.0795 - val_loss: 0.0034 - val_mda: 0.6053 - val_rmse: 0.0583 - learning_rate: 1.0000e-06
# Epoch 79/120
#
# Epoch 79: val_loss did not improve from 0.00318
# 814/814 - 4s - 5ms/step - loss: 0.0062 - mda: 0.5729 - rmse: 0.0787 - val_loss: 0.0032 - val_mda: 0.6052 - val_rmse: 0.0566 - learning_rate: 1.0000e-06
# Epoch 80/120
#
# Epoch 80: val_loss did not improve from 0.00318
# 814/814 - 4s - 5ms/step - loss: 0.0062 - mda: 0.5678 - rmse: 0.0784 - val_loss: 0.0032 - val_mda: 0.6052 - val_rmse: 0.0568 - learning_rate: 1.0000e-06
# Epoch 81/120
#
# Epoch 81: val_loss improved from 0.00318 to 0.00310, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 4s - 4ms/step - loss: 0.0063 - mda: 0.5707 - rmse: 0.0791 - val_loss: 0.0031 - val_mda: 0.6052 - val_rmse: 0.0557 - learning_rate: 1.0000e-06
# Epoch 82/120
#
# Epoch 82: val_loss did not improve from 0.00310
# 814/814 - 4s - 4ms/step - loss: 0.0063 - mda: 0.5668 - rmse: 0.0788 - val_loss: 0.0033 - val_mda: 0.6052 - val_rmse: 0.0576 - learning_rate: 1.0000e-06
# Epoch 83/120
#
# Epoch 83: val_loss did not improve from 0.00310
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5716 - rmse: 0.0791 - val_loss: 0.0031 - val_mda: 0.6052 - val_rmse: 0.0558 - learning_rate: 1.0000e-06
# Epoch 84/120
#
# Epoch 84: val_loss did not improve from 0.00310
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5712 - rmse: 0.0786 - val_loss: 0.0031 - val_mda: 0.6049 - val_rmse: 0.0562 - learning_rate: 1.0000e-06
# Epoch 85/120
#
# Epoch 85: val_loss did not improve from 0.00310
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5700 - rmse: 0.0783 - val_loss: 0.0031 - val_mda: 0.6049 - val_rmse: 0.0558 - learning_rate: 1.0000e-06
# Epoch 86/120
#
# Epoch 86: val_loss improved from 0.00310 to 0.00306, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5671 - rmse: 0.0786 - val_loss: 0.0031 - val_mda: 0.6049 - val_rmse: 0.0555 - learning_rate: 1.0000e-06
# Epoch 87/120
#
# Epoch 87: val_loss did not improve from 0.00306
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5738 - rmse: 0.0791 - val_loss: 0.0032 - val_mda: 0.6049 - val_rmse: 0.0566 - learning_rate: 1.0000e-06
# Epoch 88/120
#
# Epoch 88: val_loss improved from 0.00306 to 0.00299, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5729 - rmse: 0.0783 - val_loss: 0.0030 - val_mda: 0.6049 - val_rmse: 0.0549 - learning_rate: 1.0000e-06
# Epoch 89/120
#
# Epoch 89: val_loss improved from 0.00299 to 0.00288, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5699 - rmse: 0.0784 - val_loss: 0.0029 - val_mda: 0.6049 - val_rmse: 0.0540 - learning_rate: 1.0000e-06
# Epoch 90/120
#
# Epoch 90: val_loss did not improve from 0.00288
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5687 - rmse: 0.0788 - val_loss: 0.0030 - val_mda: 0.6049 - val_rmse: 0.0552 - learning_rate: 1.0000e-06
# Epoch 91/120
#
# Epoch 91: val_loss did not improve from 0.00288
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5702 - rmse: 0.0781 - val_loss: 0.0030 - val_mda: 0.6049 - val_rmse: 0.0553 - learning_rate: 1.0000e-06
# Epoch 92/120
#
# Epoch 92: val_loss did not improve from 0.00288
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5737 - rmse: 0.0787 - val_loss: 0.0029 - val_mda: 0.6049 - val_rmse: 0.0544 - learning_rate: 1.0000e-06
# Epoch 93/120
#
# Epoch 93: val_loss improved from 0.00288 to 0.00271, saving model to C:\Users\HW\Desktop\Deep Learning\01Assignment\a3\scr\models\LSTM_bestweights.keras
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5683 - rmse: 0.0789 - val_loss: 0.0027 - val_mda: 0.6052 - val_rmse: 0.0525 - learning_rate: 1.0000e-06
# Epoch 94/120
#
# Epoch 94: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5709 - rmse: 0.0790 - val_loss: 0.0029 - val_mda: 0.6054 - val_rmse: 0.0541 - learning_rate: 1.0000e-06
# Epoch 95/120
#
# Epoch 95: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5704 - rmse: 0.0788 - val_loss: 0.0030 - val_mda: 0.6054 - val_rmse: 0.0550 - learning_rate: 1.0000e-06
# Epoch 96/120
#
# Epoch 96: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5730 - rmse: 0.0783 - val_loss: 0.0030 - val_mda: 0.6054 - val_rmse: 0.0548 - learning_rate: 1.0000e-06
# Epoch 97/120
#
# Epoch 97: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5720 - rmse: 0.0791 - val_loss: 0.0030 - val_mda: 0.6054 - val_rmse: 0.0550 - learning_rate: 1.0000e-06
# Epoch 98/120
#
# Epoch 98: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5697 - rmse: 0.0786 - val_loss: 0.0030 - val_mda: 0.6054 - val_rmse: 0.0554 - learning_rate: 1.0000e-06
# Epoch 99/120
#
# Epoch 99: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5705 - rmse: 0.0786 - val_loss: 0.0030 - val_mda: 0.6054 - val_rmse: 0.0553 - learning_rate: 1.0000e-06
# Epoch 100/120
#
# Epoch 100: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5684 - rmse: 0.0780 - val_loss: 0.0029 - val_mda: 0.6054 - val_rmse: 0.0544 - learning_rate: 1.0000e-06
# Epoch 101/120
#
# Epoch 101: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5700 - rmse: 0.0788 - val_loss: 0.0030 - val_mda: 0.6054 - val_rmse: 0.0551 - learning_rate: 1.0000e-06
# Epoch 102/120
#
# Epoch 102: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5700 - rmse: 0.0786 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0533 - learning_rate: 1.0000e-06
# Epoch 103/120
#
# Epoch 103: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5709 - rmse: 0.0790 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0531 - learning_rate: 1.0000e-06
# Epoch 104/120
#
# Epoch 104: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5709 - rmse: 0.0787 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0530 - learning_rate: 1.0000e-07
# Epoch 105/120
#
# Epoch 105: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5732 - rmse: 0.0786 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0529 - learning_rate: 1.0000e-07
# Epoch 106/120
#
# Epoch 106: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5755 - rmse: 0.0786 - val_loss: 0.0027 - val_mda: 0.6054 - val_rmse: 0.0529 - learning_rate: 1.0000e-07
# Epoch 107/120
#
# Epoch 107: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5705 - rmse: 0.0783 - val_loss: 0.0027 - val_mda: 0.6054 - val_rmse: 0.0528 - learning_rate: 1.0000e-07
# Epoch 108/120
#
# Epoch 108: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5676 - rmse: 0.0783 - val_loss: 0.0027 - val_mda: 0.6054 - val_rmse: 0.0526 - learning_rate: 1.0000e-07
# Epoch 109/120
#
# Epoch 109: val_loss did not improve from 0.00271
# 814/814 - 4s - 4ms/step - loss: 0.0063 - mda: 0.5723 - rmse: 0.0788 - val_loss: 0.0027 - val_mda: 0.6054 - val_rmse: 0.0529 - learning_rate: 1.0000e-07
# Epoch 110/120
#
# Epoch 110: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0063 - mda: 0.5721 - rmse: 0.0788 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0532 - learning_rate: 1.0000e-07
# Epoch 111/120
#
# Epoch 111: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5688 - rmse: 0.0787 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0531 - learning_rate: 1.0000e-07
# Epoch 112/120
#
# Epoch 112: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5734 - rmse: 0.0780 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0533 - learning_rate: 1.0000e-07
# Epoch 113/120
#
# Epoch 113: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5709 - rmse: 0.0788 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0532 - learning_rate: 1.0000e-07
# Epoch 114/120
#
# Epoch 114: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5697 - rmse: 0.0788 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0532 - learning_rate: 1.0000e-08
# Epoch 115/120
#
# Epoch 115: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5735 - rmse: 0.0785 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0532 - learning_rate: 1.0000e-08
# Epoch 116/120
#
# Epoch 116: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0062 - mda: 0.5681 - rmse: 0.0782 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0531 - learning_rate: 1.0000e-08
# Epoch 117/120
#
# Epoch 117: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5686 - rmse: 0.0782 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0531 - learning_rate: 1.0000e-08
# Epoch 118/120
#
# Epoch 118: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5719 - rmse: 0.0784 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0531 - learning_rate: 1.0000e-08
# Epoch 119/120
#
# Epoch 119: val_loss did not improve from 0.00271
# 814/814 - 4s - 4ms/step - loss: 0.0063 - mda: 0.5733 - rmse: 0.0791 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0531 - learning_rate: 1.0000e-08
# Epoch 120/120
#
# Epoch 120: val_loss did not improve from 0.00271
# 814/814 - 3s - 4ms/step - loss: 0.0061 - mda: 0.5701 - rmse: 0.0782 - val_loss: 0.0028 - val_mda: 0.6054 - val_rmse: 0.0530 - learning_rate: 1.0000e-08
# DataFrame preview:
#        loss       mda      rmse  val_loss   val_mda  val_rmse  learning_rate
# 0  0.098538  0.523778  0.191801  0.034266  0.605778  0.168547         0.0001
# 1  0.017973  0.537629  0.116603  0.021154  0.608389  0.133390         0.0001
# 2  0.013638  0.542574  0.105009  0.017063  0.606556  0.122210         0.0001
# 3  0.012118  0.550390  0.099874  0.010712  0.604222  0.096799         0.0001
# 4  0.010760  0.553676  0.095471  0.011497  0.602333  0.101056         0.0001
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ------------------------------------------------------------------------------------------------------

# %%
# Plot and compare the results obtained from the three RNNs on the test data set
RNNdata = StockIndexDataset(datasets_path[0], time_steps=RNN_params['time_steps'],
                            forecast_steps=RNN_params['forecast_steps'],
                            batch_size=RNN_params['batch_size'], val_ratio=.1, test_ratio=.1)

RNN_predictions = RNN_pred_lst[0]
GRU_predictions = GRU_pred_lst[0]
LSTM_predictions = LSTM_pred_lst[0]

testset = [RNN_predictions.true_org[2], 
           RNN_predictions.predictions_org[2],
           GRU_predictions.predictions_org[2],
           LSTM_predictions.predictions_org[2]]
datetime = pd.Series(RNNdata.datetime[2].values, 
                     index = RNN_predictions.true_org[2].index)
labels = ['Actual', 'RNN', 'GRU', 'LSTM']
list_mse = [RNN_predictions.loss[2],
       GRU_predictions.loss[2],
       LSTM_predictions.loss[2]]
list_mda = [RNN_predictions.mda[2],
       GRU_predictions.mda[2],
       LSTM_predictions.mda[2]]
labels_loss = create_labels(labels, list_mse, list_mda)
plot_seqs(testset, datetime=datetime, labels=labels_loss)
# Out:
# Loading dataset... Ready for training.
